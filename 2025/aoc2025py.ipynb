# %% [markdown]
# # Day 1
#
# Something about Locked doors and codes... or somethig like that
# https://adventofcode.com/2025/day/1

# %%
def day1():
    file = open('input.txt', 'r').readlines()
    start = 50
    zeros_count = 0
    for line in file:
        amount = line[1:].strip()
        if line[0]=='L':
            start = (start + 100 - int(amount))% 100
        elif line[0]=='R':
            start = (start + int(amount))%100
        if start==0:
            zeros_count += 1
    print("Parte 1 (número de zeros):", zeros_count)

    start = 50
    zeros_count = 0
    for line in file:
        amount = int(line[1:].strip())
        if line[0]=='L':
            while amount>0:
                start = (start + 100 - 1) % 100
                amount-=1
                if start==0:
                    zeros_count += 1
        elif line[0]=='R':
            while amount>0:
                start = (start + 1 ) % 100
                amount-=1
                if start==0:
                    zeros_count += 1
    print("Parte 2 (número de clickes no zero):", zeros_count)

day1()
# Out:
# Parte 1 (número de zeros): 1150
# Parte 2 (número de clickes no zero): 6738

# %% [markdown]
# # Day 2
#
# Something about a gift shop smells RE
# https://adventofcode.com/2025/day/2

# %%
def is_valid_id(id, retxt):
    """What is a valid id? something that doesn't fit a """
    import re
    p = re.compile(retxt)
    if p.findall(str(id)):
        return id 
    else: 
        return 0

# %%
data = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"
elms = [el.split("-") for el in data.split(",")]

# %%
total1 = 0
total2 = 0
for el in elms:
    a = int(el[0])
    b = int(el[1])
    for t in range(a,b+1):
        total1 += is_valid_id(t, r"^(\d+)(\1)$")
        total2 += is_valid_id(t, r"^(\d+)(\1)+$")

print("Parte 1:", total1)
print("Parte 2:", total2)
# Out:
# Parte 1: 1227775554
# Parte 2: 4174379265

# %% [markdown]
# # Day 3
#
# --- Day 3: Lobby ---
# https://adventofcode.com/2025/day/3

# %%
data = """987654321111111
811111111111119
234234234234278
818181911112111""".split("\n")

# %%
def rec_jolt(bank, current, n_bateries):
    """Recursive solution for any number of bateries"""
    if n_bateries==0:
        return current
    ni = 0
    for i in range(len(bank)-n_bateries+1):
         if int(bank[i])>int(bank[ni]):
             ni = i
    return rec_jolt(bank[(ni+1):], current+bank[ni], n_bateries-1)

# %%
total1 = 0
total2 = 0
for bank in data:
    total1 += int(rec_jolt(bank, "", 2))
    total2 += int(rec_jolt(bank, "", 12))
print("Parte 1:", total1)
print("Parte 2:", total2)
# Out:
# Parte 1: 357
# Parte 2: 3121910778619

# %% [markdown]
# # Day 4
#
# --- Day 4: Printing Department ---
# https://adventofcode.com/2025/day/4

# %%
data="""..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@.""".split("\n")

# %%
total1 = 0
total2 = 0
cols = len(data[0])
rows = len(data)

def count_vizinhos(r,c, data):
    dd = [-1, 0, 1]
    cols = len(data[0])
    rows = len(data)
    vizinhos = -1
    for dy in dd:
        for dx in dd:
            if 0 <= r + dy < rows and 0 <= c + dx < cols:
                if data[r+dy][c+dx] == "@":
                    vizinhos += 1
    return vizinhos

for it in range(10_000): # make sure we can get out of a loop.
    mark = []
    for r in range(rows):
        for c in range(cols):
            if data[r][c] == '@':
                vizinhos = count_vizinhos(r,c,data)
                if vizinhos < 4:
                    mark.append((r,c))
                    total1 += 1
    if (it == 0):
        print("Parte 1:", total1)
    for m in mark:
        r = m[0]
        c = m[1]
        data[r]= data[r][:c] + "." + data[r][(c+1):]
    if not mark:
        break
print("Parte 2:", total1)
# Out:
# Parte 1: 13
# Parte 2: 43

# %% [markdown]
# # Day 5
#
# --- Day 5: Cafeteria ---
# https://adventofcode.com/2025/day/5

# %%
data = open("day5.txt", "r").read()
data = data.split("\n\n")
data
# Out:
# ['90876390158586-99371575473204\n141258267394867-149613795277295\n114352619044986-116556737957603\n496343406752773-499182624059648\n87359911540483-87539506199605\n85673777496030-86318273612057\n332583427607236-340324718339476\n275408809160633-280084260304217\n344896263920634-349859871462659\n373928423179738-380690534659312\n417743034648014-418071037437529\n386959031977450-390566109048119\n252452420296913-252936125659291\n111174688657181-113775499461222\n122777011189689-127167385054796\n456058047019765-456296360950336\n211397092722052-216804535064877\n221810768643796-226724511551251\n152624848414895-157415393803906\n89904241743331-90052773587988\n122777011189689-122777011189689\n416379059689149-417011326470564\n117957581766055-120046942543383\n496343406752773-499182624059648\n181104353660135-183040639636842\n253542703667153-253745956803388\n86318273612057-86643206002641\n367926272582055-367926272582055\n186437316592844-188146979854730\n515848576564116-518421101765630\n528755492634142-529984862935617\n255003475815792-255808567067998\n32657821999605-34947413077130\n256501995838725-257149482975764\n456985095151714-457493597176878\n454067611759278-454254905285358\n252207745527457-252452420296913\n327983918520728-329470490991142\n446739162991951-450851882535949\n50938120834653-56238196224716\n458304744146293-459085105793951\n502745313557205-505059448157435\n460816711199472-461519964842618\n113001096176801-114951970790650\n414608487329960-415315808855042\n459723301780494-460267795450900\n243470544687797-243470544687797\n297573056530509-301233718284875\n373928423179738-373928423179738\n260326174863435-260911923751753\n398066274502603-399211458376929\n460267795450900-461110539940075\n257149482975764-257904304553825\n251624602215023-252452420296913\n460267795450900-460816711199472\n441248141074895-441248141074895\n344896263920633-344896263920633\n193885735012008-193885735012008\n88869927745829-89268404263623\n466198614887700-466198614887700\n87539506199605-88171474116217\n185018103265947-186984250274769\n420393536451304-420531818928372\n461110539940075-461765857602637\n322910000821537-324401786180173\n243470544687797-248680587367104\n104687083217159-108357959016794\n221810768643796-226724511551251\n239681427112342-239681427112342\n256976515051550-257676370926541\n329142947096190-330556394434212\n171717858253493-179229923962319\n132077766588073-139072047044284\n306264986633411-310078028090529\n272204825838361-275408809160632\n139072047044285-139072047044285\n313531872327168-320586283321557\n475084991181179-480862930243658\n413974790503766-414801891454972\n11141570104725-11141570104725\n259068794831487-259154793582483\n89184008289399-89552781322884\n363085957395237-367926272582055\n425727121854836-428443044656873\n416086295692540-416844833117190\n466198614887701-468841081639720\n323757108257510-325454348822436\n510374251359826-512323122653236\n554198235000456-
153324\n76071059146436\n356642465746953\n269717730101950\n213215982569373\n129096003648861\n330155928599697\n483074804574399\n274522393652777\n3186010395731\n515647883180694\n523409091260622\n227252765858538\n227992100046168\n489005994340846\n491755629466279\n550706195147989\n502413482030902\n536764233752494\n195744475420682\n438578075896473\n402003055849056\n259319376114235\n222208130323604\n403936234521711\n100804574522328\n390511861943606\n318572595191055\n160389886929065\n188466464305356\n329651347488537\n482512538416220\n302122544474297\n195953623760947\n427097476543924\n412184206398442\n39957361112244\n139173317451174\n406965029436465\n146047425495746\n532076910617545\n64001031218127\n325191999419252\n299948256045416\n308524702563764\n382054174168567\n561410441323586\n467190688573899\n385039391610586\n340664876995588\n148409523639466\n438462690950354\n150498623961148\n58297508270067\n428013505901864\n439062183845584\n487768272055681\n200065511574509\n475023760400379\n288930064006407\n134609446334668\n266949872643074\n3598650469254\n400301389511327\n179382777219145\n483102225664896\n253049177124215\n406991315675070\n86779597538033\n256063526955116\n167873830134010\n506946518324093\n95560235590399\n389106647238673\n509770058801329\n160599674880171\n372405620083832\n524085421989876\n128450768102669\n314670218488691\n405732007118180\n506854658281385\n460096512969 ...

# %%
data = """3-5
10-14
16-20
12-18

1
5
8
11
17
32""".split("\n\n")

# %% [markdown]
# Part 1

# %%
valid = [ list(map(int, a.split("-"))) for a in data[0].split("\n") ]
valid = sorted(valid)
print("Size:", len(valid))

# remove duplicate lines
for i in range(len(valid)-1, 0 , -1):
    if valid[i] in valid[:i]:
        valid.remove(valid[i])
print("Size:", len(valid))
produce = list(map(int, data[1].split("\n")))
# Out:
# Size: 177
# Size: 172

# %%
def is_fresh(p, valid):
    for v in valid:
        if v[0] <= p <= v[1]:
            return 1
    return 0

fresh = 0
for p in produce:
    fresh+=is_fresh(p, valid)
print("Parte 1:", fresh)
# Out:
# Parte 1: 577

# %% [markdown]
# Part 2

# %%
# count ids, better way. Merge intervals, count totals by S=top-bottom+1

def merge_two(a,b):
    """Merge two ranges"""
    if b[1] < a[0] or b[0] > a[1]:
        return [a,b]
    return [[min(a[0], b[0]), max(a[1], b[1])]]

def merge_list(a):
    # Identify the ranges to remove by adding new ones
    to_remove = set()
    to_add = []
    for i in range(len(a)):
        for j in range(i+1,len(a)):
            t = merge_two(a[i],a[j])
            # print("merged", t, len(t))
            if len(t)==1:
                to_add.extend(t)
                to_remove.add(i)
                to_remove.add(j)
            if len(t)==2:
                pass

    # Remove ranges that were merged
    merged=a[:]
    for i in to_remove:
        while a[i] in merged:
            merged.remove(a[i])
    
    # Add the ranges that were created
    merged.extend(to_add)

    # Remove any duplicates in the list
    for i in range(len(merged)-1, 0, -1):
        if merged[i] in merged[:i]:
            merged.remove(merged[i])

    return merged if merged else a

# %%
# Repeat the merging of the list until there's no change in the output
for it in range(500):
    b = merge_list(valid)
    if b==valid:
        print("No repeats at it", it)
        break
    valid = b

# Sum each range sum it (top-bottom-1)
total2 = 0
for el in valid:
    total2 += el[1]-el[0]+1

print("Parte 2:", total2)
# Out:
# No repeats at it 8
# Parte 2: 350513176552950
